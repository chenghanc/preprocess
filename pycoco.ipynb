# %%
# %matplotlib inline
from pycocotools.coco import COCO
import requests
import csv
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (8.0, 10.0)

# %%
coco = COCO('/home/nechk/.mxnet/datasets/coco/annotations/instances_train2017.json')
cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print('COCO categories: \n{}\n'.format(' '.join(nms)))
# Out:
# loading annotations into memory...
# Done (t=10.58s)
# creating index...
# index created!
# COCO categories:
# person bicycle car motorcycle airplane bus train truck boat traffic light fire hydrant stop sign parking meter bench bird cat dog horse sheep cow elephant bear zebra giraffe backpack umbrella handbag tie suitcase frisbee skis snowboard sports ball kite baseball bat baseball glove skateboard surfboard tennis racket bottle wine glass cup fork knife spoon bowl banana apple sandwich orange broccoli carrot hot dog pizza donut cake chair couch potted plant bed dining table toilet tv laptop mouse remote keyboard cell phone microwave oven toaster sink refrigerator book clock vase scissors teddy bear hair drier toothbrush

# %%
catIds = coco.getCatIds(catNms=['toaster'])
imgIds = coco.getImgIds(catIds=catIds )
images = coco.loadImgs(imgIds)
print("imgIds: ", imgIds)
print("images: ", images)
# Out:
# imgIds:  [314370, 410627, 551427, 159240, 346121, 49673, 533003, 497160, 349709, 33297, 24081, 439827, 121366, 294937, 403482, 378905, 576030, 497698, 481828, 528938, 544299, 69675, 179242, 71726, 429614, 554037, 426551, 254520, 271930, 564283, 491579, 50753, 418882, 203843, 352841, 28239, 347727, 387153, 554066, 225363, 282707, 282711, 228953, 387678, 215135, 11360, 272480, 147042, 531552, 8292, 537335, 116334, 387696, 544371, 353398, 373880, 419449, 111737, 147073, 515202, 552066, 396421, 246409, 515210, 215691, 349322, 512140, 494217, 27285, 161941, 212633, 320667, 398494, 119966, 204448, 184994, 360101, 147122, 493235, 307379, 563898, 63676, 349376, 214725, 246478, 558798, 267988, 434389, 226517, 318677, 48863, 126182, 233703, 485099, 275695, 436975, 325362, 537844, 514294, 193271, 576247, 467705, 484090, 255226, 62716, 275197, 463613, 199422, 59648, 457986, 93959, 435466, 121612, 291597, 330513, 422161, 525075, 355603, 280857, 530201, 308507, 557339, 432417, 411941, 511781, 9194
# ...

# %%
for im in images:
    print("im: ", im)
    img_data = requests.get(im['coco_url']).content
    with open('downloaded_images/' + im['file_name'], 'wb') as handler:
        handler.write(img_data)
# Out:
# im:  {'license': 1, 'file_name': '000000314370.jpg', 'coco_url': 'http://images.cocodataset.org/train2017/000000314370.jpg', 'height': 427, 'width': 640, 'date_captured': '2013-11-14 22:08:30', 'flickr_url': 'http://farm9.staticflickr.com/8218/8360971161_0fd033f970_z.jpg', 'id': 314370}
# im:  {'license': 3, 'file_name': '000000410627.jpg', 'coco_url': 'http://images.cocodataset.org/train2017/000000410627.jpg', 'height': 640, 'width': 427, 'date_captured': '2013-11-14 19:54:42', 'flickr_url': 'http://farm8.staticflickr.com/7264/7569202194_998ab865ab_z.jpg', 'id': 410627}
# im:  {'license': 1, 'file_name': '000000551427.jpg', 'coco_url': 'http://images.cocodataset.org/train2017/000000551427.jpg', 'height': 480, 'width': 640, 'date_captured': '2013-11-14 17:23:33', 'flickr_url': 'http://farm7.staticflickr.com/6068/6135569500_fdbbc89811_z.jpg', 'id': 551427}
# ...

# %%
#Download annotations
with open('annotations_download_' + 'toaster' + '.csv', mode='w', newline='') as annot:
    for im in images:
        annIds = coco.getAnnIds(imgIds=im['id'], catIds=catIds, iscrowd=None)
        anns = coco.loadAnns(annIds)
        for i in range(len(anns)):
            annot_writer = csv.writer(annot)
            #annot_writer.writerow([im['coco_url'], anns[i]['bbox'][0], anns[i]['bbox'][1], anns[i]['bbox'][0] + anns[i]['bbox'][2], anns[i]['bbox'][1] + anns[i]['bbox'][3], classes])
            annot_writer.writerow(['downloaded_images/' + im['file_name'], int(round(anns[i]['bbox'][0])), int(round(anns[i]['bbox'][1])), int(round(anns[i]['bbox'][0] + anns[i]['bbox'][2])), int(round(anns[i]['bbox'][1] + anns[i]['bbox'][3])), 'toaster'])
            #print("anns: ", im['coco_url'], anns[i]['bbox'][0], anns[i]['bbox'][1], anns[i]['bbox'][0] + anns[i]['bbox'][2], anns[i]['bbox'][1] + anns[i]['bbox'][3], 'person')
            #annot.close()
